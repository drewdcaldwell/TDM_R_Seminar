# %% [markdown]
# # Project 1 -- [Drew] [Caldwell]

# %% [markdown]
# **TA Help:** N/A
#
# **Collaboration:** N/A

# %% [markdown]
# ## Question 1

# %% [markdown]
# Import the pandas python library

# %%
import pandas as pd

# %% [markdown]
# Create a data frame of the airports csv file

# %%
myDF = pd.read_csv("/anvil/projects/tdm/data/flights/subset/airports.csv")

# %% [markdown]
# Display the first 5 rows of the dataframe

# %%
myDF.head()
# Out:
#   iata               airport              city state country        lat  \
# 0  00M              Thigpen        Bay Springs    MS     USA  31.953765
# 1  00R  Livingston Municipal        Livingston    TX     USA  30.685861
# 2  00V           Meadow Lake  Colorado Springs    CO     USA  38.945749
# 3  01G          Perry-Warsaw             Perry    NY     USA  42.741347
# 4  01J      Hilliard Airpark          Hilliard    FL     USA  30.688012
#
#          long
# 0  -89.234505
# 1  -95.017928
# 2 -104.569893
# 3  -78.052081
# 4  -81.905944

# %% [markdown]
# This is the end of Question 1. I learned how to import a python library into a jupyter notebook, how to read a csv file in python using pandas, and display the first 5 rows of the dataframe.

# %% [markdown]
# ## Question 2

# %% [markdown]
# If I change the kernel to "seminar-r" notice that we do not have to begin the code with %%R, like we would if the kernel was not seminar-r.

# %%
# %%R
# myDF <- read.csv("/anvil/projects/tdm/data/flights/subset/airports.csv")
# head(myDF)
# Out:
#   iata              airport             city state country      lat       long
# 1  00M             Thigpen       Bay Springs    MS     USA 31.95376  -89.23450
# 2  00R Livingston Municipal       Livingston    TX     USA 30.68586  -95.01793
# 3  00V          Meadow Lake Colorado Springs    CO     USA 38.94575 -104.56989
# 4  01G         Perry-Warsaw            Perry    NY     USA 42.74135  -78.05208
# 5  01J     Hilliard Airpark         Hilliard    FL     USA 30.68801  -81.90594
# 6  01M    Tishomingo County          Belmont    MS     USA 34.49167  -88.20111

# %% [markdown]
# In this question I learned how to change the kernel and ran some R code

# %% [markdown]
# ## Question 3

# %% [markdown]
# Here we will display the 50 states and how many airports are located in each state

# %%
# %%R
# table(myDF$state)
# Out:
#  AK  AL  AR  AS  AZ  CA  CO  CQ  CT  DC  DE  FL  GA  GU  HI  IA  ID  IL  IN  KS
# 263  73  74   3  59 205  49   4  15   1   5 100  97   1  16  78  37  88  65  78
#  KY  LA  MA  MD  ME  MI  MN  MO  MS  MT  NC  ND  NE  NH  NJ  NM  NV  NY  OH  OK
#  50  55  30  18  34  94  89  74  72  71  72  52  73  14  35  51  32  97 100 102
#  OR  PA  PR  RI  SC  SD  TN  TX  UT  VA  VI  VT  WA  WI  WV  WY
#  57  71  11   6  52  57  70 209  35  47   5  13  65  84  24  32

# %% [markdown]
# In this code we're going to sort the number of airports in a state ascending

# %%
# %%R
# sort(table(myDF$state))
# Out:
#  DC  GU  AS  CQ  DE  VI  RI  PR  VT  NH  CT  HI  MD  WV  MA  NV  WY  ME  NJ  UT
#   1   1   3   4   5   5   6  11  13  14  15  16  18  24  30  32  32  34  35  35
#  ID  VA  CO  KY  NM  ND  SC  LA  OR  SD  AZ  IN  WA  TN  MT  PA  MS  NC  AL  NE
#  37  47  49  50  51  52  52  55  57  57  59  65  65  70  71  71  72  72  73  73
#  AR  MO  IA  KS  WI  IL  MN  MI  GA  NY  FL  OH  OK  CA  TX  AK
#  74  74  78  78  84  88  89  94  97  97 100 100 102 205 209 263

# %% [markdown]
# Here I learned how to count the occurences of specific values in columns and display them in a table.

# %% [markdown]
# ## Question 4

# %% [markdown]
# In this code we will look at the number of times each brand occurs. Since we know that each prduct is only listed once. This is the number of products per brand.

# %%
# %%R
# myDF <- read.csv("/anvil/projects/tdm/data/icecream/combined/products.csv")
# table(myDF$brand)
# Out:
#      bj breyers      hd talenti
#      57      69      70      45

# %% [markdown]
# Now in this code we will look at the count of the number of reviews made per brand.

# %%
# %%R
# myDF <- read.csv("/anvil/projects/tdm/data/icecream/combined/reviews.csv")
# table(myDF$brand)
# Out:
#      bj breyers      hd talenti
#    7943    5007    4655    4069

# %% [markdown]
# Here we were able to apply what we used in question 3 and gain some valuable information about different ice cream brands.

# %% [markdown]
# ## Question 5

# %% [markdown]
# Here we're going to create a bar graph that displays the number of products per ice cream brand

# %%
# %%R
# myDF <- read.csv("/anvil/projects/tdm/data/icecream/combined/products.csv")
# plot(table(myDF$brand))

# %% [markdown]
# Now in this we are going to create a bar graph that allows us to visualize the number of reviews that have been created per ice cream brand

# %%
# %%R
# myDF <- read.csv("/anvil/projects/tdm/data/icecream/combined/reviews.csv")
# plot(table(myDF$brand))

# %% [markdown]
# In this question I learned how to create a bar graph for different tables based on specific columns and the count of occurences of the values in that column.

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
