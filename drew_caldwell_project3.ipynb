# %% [markdown]
# # Project 3 -- [Drew] [Caldwell]

# %% [markdown]
# **TA Help:** N/A
#
# **Collaboration:** N/A

# %% [markdown]
# ## Question 1

# %% [markdown]
# Here we are laoding a data set using the fread

# %%
library(data.table)
myDF <- fread("/anvil/projects/tdm/data/flights/subset/1990.csv")

# %% [markdown]
# ## Question 2

# %% [markdown]
# Here we are loading the dataset then using tapply to find the sum for the 4 different regions of stores transactions

# %%
library(data.table)
myDF <- fread("/anvil/projects/tdm/data/8451/The_Complete_Journey_2_Master/5000_transactions.csv")

# %%
tapply(myDF$SPEND, myDF$STORE_R, sum, na.rm = TRUE)
# Out:
#  CENTRAL     EAST    SOUTH     WEST
#  8897305 11699447  7957921  9680107

# %% [markdown]
# We see here that the East region spent the most, and the South region spent the least.

# %% [markdown]
# ## Question 3

# %% [markdown]
# Here we are going to load the dataset as before, transform the date so that we have a year variable that we can sort by, and then sum the years 2016 and 2017

# %%
library(data.table)
myDF <- fread("/anvil/projects/tdm/data/8451/The_Complete_Journey_2_Master/5000_transactions.csv")

# %% [markdown]
# Now I am going to create a new table that will have the total spent per year, and then display the total spent in 2016 and 207

# %%
total_spend_per_year <- tapply(myDF$SPEND, myDF$YEAR, sum, na.rm = TRUE)
print(total_spend_per_year[c("2016", "2017")])
# Out:
#     2016     2017
# 19051720 19183059

# %% [markdown]
# So in 2016 we see a total of 19,051,720 and in 2017 19,183,059 spent

# %% [markdown]
# ## Question 4

# %% [markdown]
# Here we are going to load the data and look at the average height per country in the olympics

# %%
library(data.table)
myDF <- fread("/anvil/projects/tdm/data/olympics/athlete_events.csv")
tapply(myDF$Height, myDF$NOC, mean, na.rm = TRUE)
# Out:
#      AFG      AHO      ALB      ALG      AND      ANG      ANT      ANZ
# 170.5926 177.2941 173.0000 174.7029 173.7037 178.2041 175.1217 176.7308
#      ARG      ARM      ARU      ASA      AUS      AUT      AZE      BAH
# 176.6047 171.9378 173.2195 175.6667 176.8740 177.3697 172.7174 177.4407
#      BAN      BAR      BDI      BEL      BEN      BER      BHU      BIH
# 166.1875 176.5990 172.6316 176.1432 173.6833 177.4058 166.5172 178.6339
#      BIZ      BLR      BOH      BOL      BOT      BRA      BRN      BRU
# 175.0548 174.2564 174.0000 171.2957 175.8095 177.6371 173.4245 166.1111
#      BUL      BUR      CAF      CAM      CAN      CAY      CGO      CHA
# 172.8309 176.0000 179.2766 166.7193 174.9787 179.5068 174.5854 176.5588
#      CHI      CHN      CIV      CMR      COD      COK      COL      COM
# 174.9870 172.6027 176.4151 173.6346 175.3582 171.3243 169.9152 170.8667
#      CPV      CRC      CRO      CRT      CUB      CYP      CZE      DEN
# ...

# %% [markdown]
# Here we can see the average height of each country that competed in the olympics

# %% [markdown]
# ## Question 5

# %% [markdown]
# Here we take a similar approach as in Q4 but instead we will categorize by sport and when we display we will sort the height

# %%
averageHeightPerSport <- tapply(myDF$Height, myDF$Sport, mean, na.rm = TRUE)

# Sort the average results by height
sort(averageHeightPerSport, decreasing = TRUE)
# Out:
#                Basketball                Volleyball          Beach Volleyball
#                  190.8699                  186.9948                  186.1450
#                Water Polo                    Rowing                  Handball
#                  184.8346                  184.1722                  183.3846
#                  Baseball                Tug-Of-War                 Bobsleigh
#                  182.5993                  182.4800                  181.4375
#              Motorboating                Ice Hockey                    Tennis
#                  181.0000                  178.9013                  178.8981
#                  Swimming                  Canoeing              Jeu De Paume
#                  178.5625                  178.5396                  178.5000
#                   Sailing         Modern Pentathlon                   Fencing
#                  178.2622                  177.9443                  177.1642
# ...

# %% [markdown]
# So we have gathered that the tallest sport is Basketball, followed by volleyball. Both of these make sense in terms of what is needed to be competitive in the sports. Likewise it's not surprising that Gy

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
